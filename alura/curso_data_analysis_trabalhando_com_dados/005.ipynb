# %%
# %matplotlib inline

# %%
import pandas as pd
data = pd.read_excel('data_analysis/005.xlsx')

# %%
data.columns = ['day', 'sales']

# %%
data.head()
# Out:
#          day  sales  aux_x
# 0 2015-01-01     51      0
# 1 2015-01-02     54      1
# 2 2015-01-03     18      2
# 3 2015-01-04     19      3
# 4 2015-01-05     57      4

# %%
data.plot('day', 'sales', figsize=(15, 5))

# %%
import seaborn as sns

# %%
data['aux_x'] = range(len(data))

# %%
sns.lmplot(x='aux_x', y='sales', data=data)

# %%
sns.lineplot(x='day', y='sales', data=data)
