# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos.head(5)
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 1  Cátia     27    F    2.5     False
# 2  Denis     56    M    5.0     False
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True

# %%
alunos.query('Aprovado')
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
aprovados = alunos.query('Aprovado')

# %%
aprovados.head()
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
alunas_aprovadas = alunos.query('Sexo == "F" and Aprovado')

# %%
alunas_aprovadas
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
alunos_entre_10_e_20_anos = alunos[alunos.Idade.isin(range(10, 20))]

# %%
alunos_maior_que_40_anos = alunos.query('Idade >= 40')

# %%
alunos_entre_10_e_20_anos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False

# %%
alunos_maior_que_40_anos
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 2  Denis     56    M    5.0     False
# 4  Bruna     42    F    8.2      True

# %%
alunos_entre_10_e_20_anos_ou_maior_que_40_anos = alunos_entre_10_e_20_anos.combine_first(alunos_maior_que_40_anos)

# %%
alunos_entre_10_e_20_anos_ou_maior_que_40_anos
# Out:
#      Nome  Idade Sexo  Notas Aprovado
# 0     Ary   15.0    M    7.5     True
# 2   Denis   56.0    M    5.0    False
# 4   Bruna   42.0    F    8.2     True
# 6  Carlos   19.0    M    6.0    False

# %%
alunos_reprovados = alunos.query('not Aprovado')

# %%
alunos_reprovados[['Nome', 'Sexo', 'Idade']]
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
alunos.sort_values(by='Idade')[:3]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True
