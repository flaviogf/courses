# %%
import pandas as pd

# %%
dados_aluguel = pd.read_csv('dados/aluguel.csv')

# %%
dados_aluguel
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# 5               Apartamento;Vista Alegre;3;1;0;70;1200;;
# 6              Apartamento;Cachambi;2;0;0;50;1300;301;17
# 7      Casa de Condomínio;Barra da Tijuca;5;4;5;750;2...
# 8               Casa de Condomínio;Ramos;2;2;0;65;1000;;
# 9      Conjunto Comercial/Sala;Centro;0;3;0;695;35000...
# 10                    Apartamento;Centro;1;0;0;36;1200;;
# 11               Apartamento;Grajaú;2;1;0;70;1500;642;74
# 12     Apartamento;Lins de Vasconcelos;3;1;1;90;1500;...
# 13           Apartamento;Copacabana;1;0;1;40;2000;561;50
# 14               Quitinete;Copacabana;1;0;0;27;1800;501;
# ...

# %%
dados_aluguel = pd.read_csv('dados/aluguel.csv', sep=";")

# %%
dados_aluguel
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 0                    Quitinete                Copacabana        1      0
# 1                         Casa           Jardim Botânico        2      0
# 2      Conjunto Comercial/Sala           Barra da Tijuca        0      4
# 3                  Apartamento                    Centro        1      0
# 4                  Apartamento              Higienópolis        1      0
# 5                  Apartamento              Vista Alegre        3      1
# 6                  Apartamento                  Cachambi        2      0
# 7           Casa de Condomínio           Barra da Tijuca        5      4
# 8           Casa de Condomínio                     Ramos        2      2
# 9      Conjunto Comercial/Sala                    Centro        0      3
# 10                 Apartamento                    Centro        1      0
# 11                 Apartamento                    Grajaú        2      1
# ...

# %%
type(dados_aluguel)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(dados_aluguel)
# Out:
# ['Area',
#  'Bairro',
#  'Condominio',
#  'IPTU',
#  'Quartos',
#  'Suites',
#  'T',
#  'Tipo',
#  'Vagas',
#  'Valor',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
# ...

# %%
dados_aluguel.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
pd.DataFrame(dados_aluguel.dtypes)
# Out:
#                   0
# Tipo         object
# Bairro       object
# Quartos       int64
# Vagas         int64
# Suites        int64
# Area          int64
# Valor       float64
# Condominio  float64
# IPTU        float64

# %%
tipos_dado = pd.DataFrame(data=dados_aluguel.dtypes, columns=['Tipo'])

# %%
dir(tipos_dado)
# Out:
# ['T',
#  'Tipo',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
dir(tipos_dado.columns)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__inv__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
# ...

# %%
tipos_dado.columns.names
# Out:
# FrozenList([None])

# %%
tipos_dado.columns.name = 'Variavel'

# %%
tipos_dado
# Out:
# Variavel       Tipo
# Tipo         object
# Bairro       object
# Quartos       int64
# Vagas         int64
# Suites        int64
# Area          int64
# Valor       float64
# Condominio  float64
# IPTU        float64

# %%
dados_aluguel.shape
# Out:
# (32960, 9)
